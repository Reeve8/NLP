# %% [markdown]
# #Evaluating Language Models

# %% [markdown]
# #There are two ways to evaluate language models in NLP: Extrinsic evaluation and Intrinsic evaluation.
# #Intrinsic evaluation captures how well the model captures what it is supposed to capture, like probabilities.
# #Extrinsic evaluation (or task-based evaluation) captures how useful the model is in a particular task.

# %% [markdown]
# #Extrinsic evaluation is the best way to evaluate the performance of a language model by embedding it in an application and measuring how much the application improves.
#
# #It is an end-to-end evaluation where we can understand if a particular improvement in a component is really going to help the task at hand.
# #Example: For speech recognition, we can compare the performance of two language models by running the speech recognizer twice, once with each language model, and seeing which gives the more accurate transcription.

# %% [markdown]
# #Intrinsic Evaluation
#
# #An intrinsic evaluation metric is one that measures the quality of a model-independent of any application.

# %% [markdown]
# #Types of Performance Evaluation Metrics
#
# ##1. Accuracy: Accuracy is a popular metric, which is used to represent the percentage of the questions that an MRC system answers accurately. To recapitulate, the ratio between the total number of questions (N) in MRC and the number of questions that the system answers correctly (M).
#
# #Accuracy=M/N

# %% [markdown]
# #Exact Match (EM): EM represents the percentage of questions that the system-generated answer exactly matches the correct answer, the answers can be an entity or word, phrase, sub-sequence, or a sentence, but the system generated answer and the correct answer should be equal. EM may not work properly in factoid questions because the answer may not have a part of the correct answer.
# #Exact Match=M/N

# %% [markdown]
# #Precision, Recall and F1 score (F Score)

# %% [markdown]
# #ROUGE (Recall-Oriented Understudy for Gisting Evaluation): ROUGE measure is used to evaluate the performance for text summarization, Machine Translation, MRC models.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# Where RS is Reference Summaries, n is the n-gram length, Count(gram_n) is the total number of n-gram in the candidate text and generated text.

# %% [markdown]
# #BLEU (Bilingual Evaluation Understudy):  BLEU is a Corpus or text-oriented Metric and measures the relatedness between the candidates to the reference texts. The result nears one of the texts with similar semantics.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #METEOR (Metric for Evaluation of Translation with Explicit ORdering): METEOR is a combination of Recall and Accuracy to evaluate the model performance and the score is determined by the harmonic mean of precision and recall.

# %% [markdown]
# #METEOR can be measured in connection with Fmean and penalty that can be estimated using equation and equation. The penalty is calculated with the total number of matched words and the number of chunks, where m is the total number of matched words, ch is the number of chunks, and α, β, γ are the parameters.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #	HEQ (Human Equivalence Score): The HEQ is the recently developed metric for judging whether the output of the system is equivalent to the output of an ordinary person. HEQ is mostly suitable for Conversational MRC due to the presence of multiple valid answers. The HEQ score can be measured by the number of questions N and the M is the number of questions that reaches the token-level F1 of human judgment.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Entropy, Cross entropy, and Perplexity are common metrics for evaluating the performance of language models in NLP.

# %% [markdown]
# #Entropy is a measure of uncertainty or unpredictability in a system. In information theory, it quantifies the average amount of information produced by a stochastic process. For a discrete random variable X with probability mass function P(X), the entropy H(X) is defined as:
# ![image.png](data:image/png;base64,...)
# #where the base of the logarithm determines the unit of entropy (typically base 2 is used, so entropy is measured in bits). Higher entropy indicates higher uncertainty or disorder.

# %% [markdown]
# #Cross entropy is a measure of the difference between two probability distributions. It is often used to compare the "true" distribution of data with a predicted distribution. Given two probability distributions P and Q over the same domain, the cross entropy H(P, Q) is defined as:
#
# ![image.png](data:image/png;base64,...)
#
# #Cross entropy reaches its minimum when P and Q are identical. It is widely used in machine learning for tasks like classification, where it serves as a loss function.

# %% [markdown]
# #Perplexity is a measure of how well a probability distribution or a probability model predicts a sample. It is commonly used in natural language processing to evaluate language models. For a language model, given a sequence of words w1,w2,w3......wn, the perplexity is calculated as:
# ![image.png](data:image/png;base64,...)
#
# #Perplexity can be interpreted as the average branching factor of a language model. Lower perplexity indicates that the model is better at predicting the sample.

# %% [markdown]
# #Natural Language Generation
# ##1. https://cloud.google.com/dialogflow
# ##2. https://dev.botframework.com/
# ##3. https://www.ibm.com/products/watsonx-ai?utm_content=SRCWW&p1=Search&p4=43700079462736455&p5=p&gad_source=1&gclid=CjwKCAiAxaCvBhBaEiwAvsLmWPCNGaR0017-ssMC-IpFQviK4qhIxRvEPHb72qQygBIsiEEc6gksFRoC2RIQAvD_BwE&gclsrc=aw.ds
# ##4. https://rasa.com/
# ##5. https://botpress.com/
# ##6. https://chatfuel.com/
# ##7. https://aws.amazon.com/pm/lex/?gclid=CjwKCAiAxaCvBhBaEiwAvsLmWKrXPNiptmlzkUjA1VAie5wGqqkt4r6dpb3C8fadS7U9HfJxav3-mBoCLBsQAvD_BwE&trk=436e9c39-382a-42a6-a49f-4cdbdfe8cadc&sc_channel=ps&ef_id=CjwKCAiAxaCvBhBaEiwAvsLmWKrXPNiptmlzkUjA1VAie5wGqqkt4r6dpb3C8fadS7U9HfJxav3-mBoCLBsQAvD_BwE:G:s&s_kwcid=AL!4422!3!652868433334!e!!g!!lex%20chat!19910624536!147207932349
# ##8. https://wit.ai/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Natural Language Generation
# #Text-to-Text
# ##1. Machine Translation : Automatically translating between various human languages
# ##2. Text Summarization : Summarizing a (big) text document into a shorter summary/abstract.
#
# #Data-to-Text
#
# ##Image Captioning : Describe the image in a short sentence.
# ##Video Captioning : Generate captions that change with the video scenes.
# ##Business Intelligence : Creating text summaries of data from conventional databases (e.g SQL)
#
# #Ideas-to-Text
# ##Poetry/Song Generation : Generating a song from a few keywords or mimicking the style of a certain artist.
# ##Fake News : Automatically generating news items that look credible but are not.
# #Dialog Systems (Chatbots)
# ##Goal Oriented : Chatting with a computer system (agent) with a specific purpose (e.g. booking a flight)
# #Open ended conversations : When the conversation with the agent is casual chit-chat but has the components of information, emotion and human like empathy.
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #https://blog.research.google/2018/05/duplex-ai-system-for-natural-conversation.html
#
# #https://www.youtube.com/watch?v=D5VN56jQMWM

# %% [markdown]
# > Indented block
